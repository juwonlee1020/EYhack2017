# %%
#import statements
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
#Load dataset
kickstarter_data = pd.read_csv("Kickstarter_preprocessed.csv")

# %%
#Check what the dataset looks like
kickstarter_data.head(5)
# Out:
#    Unnamed: 0                                                url  \
# 0           1  https://www.kickstarter.com/projects/100143389...
# 1           2  https://www.kickstarter.com/projects/100146151...
# 2           3  https://www.kickstarter.com/projects/100217190...
# 3           4  https://www.kickstarter.com/projects/100296962...
# 4           5  https://www.kickstarter.com/projects/100345889...
#
#                                           urlProfile  \
# 0  https://www.kickstarter.com/profile/1001433890...
# 1  https://www.kickstarter.com/profile/100146151/...
# 2  https://www.kickstarter.com/profile/1002171905...
# 3  https://www.kickstarter.com/profile/1002969621...
# 4  https://www.kickstarter.com/profile/1003458897...
#
#                                        campaignTitle        category  \
# 0                                         Die Kamera       Webseries
# 1                          "Flores" Documentary Film     Documentary
# 2  F(r)iction #7 - A Fine Art & Literature Collec...         Fiction
# 3                                      Design Canada  Graphic Design
# 4  New HyperKid Book - The Cyborg at the End of t...     Young Adult
#
#                        creator      goal             location  \
# 0               Georg Melichar  58367.10      Vienna, Austria
# 1            Francisco Viveros   6994.52  Mexico City, Mexico
# 2          Tethered by Letters   3000.00           Denver, CO
# 3              Jessica Edwards  80000.00    Vancouver, Canada
# 4  Richard Daub & Emerson Daub  10000.00     White Plains, NY
#
#    totalNumberBackers  numComments      ...                    endDate  \
# 0                   1            0      ...        2017-03-31 14:30:00
# 1                  51            1      ...        2017-04-20 00:32:00
# 2                 119            5      ...        2017-04-22 14:45:00
# 3                1483           34      ...        2017-03-30 22:00:00
# 4                   0            0      ...        2017-04-25 11:41:00
#
#              startDate  estimatedDelivery   experience  canceled  \
# 0  2017-03-01 15:30:00         229.177083     1.141667     False
# 1  2017-02-19 01:32:00         254.523232    73.341667     False
# 2  2017-03-23 14:45:00          16.135417   683.740278     False
# 3  2017-02-28 13:09:00         149.690476  2265.436806     False
# 4  2017-03-26 11:41:00           5.513194     9.996528      True
#
#   averageBackersRequired  aggregatedPerkValue overPaying shippingWorld  \
# 0             734.177358                  0.0       1.06           1.0
# 1             179.346667                802.0    7133.82           1.0
# 2              75.000000               3473.0     951.00           1.0
# 3             290.909091              86240.0   12938.00           1.0
# 4             571.428571                  0.0       0.00           0.5
#
#   numCompetitors
# 0             26
# 1             88
# 2             64
# 3             23
# 4             13
#
# [5 rows x 54 columns]

# %%
#list of columns
columns = kickstarter_data.columns.tolist() #column list
columns
# Out:
# ['Unnamed: 0',
#  'url',
#  'urlProfile',
#  'campaignTitle',
#  'category',
#  'creator',
#  'goal',
#  'location',
#  'totalNumberBackers',
#  'numComments',
#  'numUpdates',
#  'totalPledge',
#  'backed',
#  'comments',
#  'created',
#  'joinKS',
#  'facebookFriends',
#  'urlCreator',
#  'websites',
#  'mainCategory',
#  'countryState',
#  'city',
#  'projectsWeLove',
#  'continent',
#  'valuta',
#  'success',
#  'percentageGoal',
#  'lowestPerk',
#  'highestPerk',
#  'medianPerk',
#  'lowestPerkPriceOriginal',
#  'numPerks',
#  'numCollaborators',
#  'noFacebookFriends',
#  'numSuccessfulCampaigns',
#  'numLiveCampaigns',
#  'pastSuccessRate',
#  'totWordCount',
#  'mainVideo',
#  'numAdditionalVideos',
#  'numImages',
#  'viewGallery',
#  'addedPerks',
#  'duration',
#  'endDate',
#  'startDate',
#  'estimatedDelivery',
#  'experience',
#  'canceled',
#  'averageBackersRequired',
#  'aggregatedPerkValue',
#  'overPaying',
#  'shippingWorld',
#  'numCompetitors']

# %%
#Filter out unnecessary columns -at launch point
no_need = ["Unnamed: 0","url", "urlProfile", "url", "campaignTitle", "aggregatedPerkValue","creator", "location","totalNumberBackers", "numComments","numUpdates","totalPledge","backed","comments","created","joinKS","urlCreator","websites","countryState","city","projectsWeLove","continent","valuta","lowestPerkPriceOriginal","noFacebookFriends","pastSuccessRate","numAdditionalVideos","viewGallery","addedPerks","endDate","startDate","experience","percentageGoal","numLiveCampaigns","averageBackersRequired","canceled","highestPerk","lowestPerk","overPaying","shippingWorld","numCompetitors"]
kickstarter = kickstarter_data.copy() #kickstarter_data remains the same
kickstarter.drop(no_need, axis=1, inplace=True)
kickstarter.head(10)
# Out:
#          category      goal  facebookFriends  mainCategory  success  \
# 0       Webseries  58367.10            737.0  Film & Video        0
# 1     Documentary   6994.52           2480.0  Film & Video        1
# 2         Fiction   3000.00            461.0    Publishing        1
# 3  Graphic Design  80000.00            574.5        Design        1
# 4     Young Adult  10000.00            574.5    Publishing        0
# 5     Digital Art    385.91            574.5           Art        0
# 6     Documentary   3500.00            702.0  Film & Video        1
# 7            Food  10000.00           4981.0          Food        0
# 8             Art   2253.30            270.0           Art        1
# 9       Sculpture  81289.00           5000.0           Art        0
#
#    medianPerk  numPerks  numCollaborators  numSuccessfulCampaigns  \
# 0        79.5         4                 0                       0
# 1        39.0        11                 0                       1
# 2        40.0        20                 0                       4
# 3       275.0        28                 0                       2
# 4        17.5         6                 0                       0
# 5        13.5         8                 0                       0
# 6       300.0         9                 0                       1
# 7       100.0         1                 0                       0
# 8        26.0         3                 0                       1
# 9       125.0         6                 0                       0
#
#    totWordCount  mainVideo  numImages   duration  estimatedDelivery
# 0           253          1          0  29.958333         229.177083
# 1          1165          1          7  59.958333         254.523232
# 2          1371          1         12  30.000000          16.135417
# 3          1040          1         34  30.368715         149.690476
# 4          1641          1          0  30.000000           5.513194
# 5           158          0          4  31.000000          15.492361
# 6           897          1          0  21.628322         135.277778
# 7           197          1          0  59.958333         -20.712500
# 8           305          1          0  12.559942          -1.666667
# 9           289          0          0  30.000000         226.521528

# %%
kc_film_video = kickstarter[kickstarter["mainCategory"]=="Film & Video"].copy()
kc_publishing = kickstarter[kickstarter["mainCategory"]=="Publishing"].copy()
kc_design = kickstarter[kickstarter["mainCategory"]=="Design"].copy()
kc_art = kickstarter[kickstarter["mainCategory"]=="Art"].copy()
kc_food = kickstarter[kickstarter["mainCategory"]=="Food"].copy()
kc_fashion = kickstarter[kickstarter["mainCategory"]=="Fashion"].copy()
kc_games = kickstarter[kickstarter["mainCategory"]=="Games"].copy()
kc_theater = kickstarter[kickstarter["mainCategory"]=="Theater"].copy()
kc_music = kickstarter[kickstarter["mainCategory"]=="Music"].copy()
kc_crafts = kickstarter[kickstarter["mainCategory"]=="Crafts"].copy()
kc_technology = kickstarter[kickstarter["mainCategory"]=="Technology"].copy()
kc_comics = kickstarter[kickstarter["mainCategory"]=="Comics"].copy()

# %%
kc_dfs = [kc_film_video, kc_publishing, kc_design, kc_art, kc_food, kc_fashion, kc_games, kc_theater, kc_music, kc_crafts, kc_technology, kc_comics]

for df in kc_dfs:
    df.drop(["category"], axis=1)
    correlation_matrix = df.corr()

# %%
sns.heatmap(kc_film_video.drop(["category"], axis=1).corr())
show()
sns.heatmap(kc_publishing.drop(["category"], axis=1).corr())
show()
