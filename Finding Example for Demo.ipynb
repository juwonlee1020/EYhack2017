# %%
#import statements
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
kickstarter_data = pd.read_csv("Kickstarter_preprocessed.csv")

# %%
#Check what the dataset looks like
kickstarter_data.head(5)
# Out:
#    Unnamed: 0                                                url  \
# 0           1  https://www.kickstarter.com/projects/100143389...
# 1           2  https://www.kickstarter.com/projects/100146151...
# 2           3  https://www.kickstarter.com/projects/100217190...
# 3           4  https://www.kickstarter.com/projects/100296962...
# 4           5  https://www.kickstarter.com/projects/100345889...
#
#                                           urlProfile  \
# 0  https://www.kickstarter.com/profile/1001433890...
# 1  https://www.kickstarter.com/profile/100146151/...
# 2  https://www.kickstarter.com/profile/1002171905...
# 3  https://www.kickstarter.com/profile/1002969621...
# 4  https://www.kickstarter.com/profile/1003458897...
#
#                                        campaignTitle        category  \
# 0                                         Die Kamera       Webseries
# 1                          "Flores" Documentary Film     Documentary
# ...

# %%
kick_fail = kickstarter_data[(kickstarter_data["success"]==0) & (kickstarter_data["mainCategory"]=="Film & Video")]

# %%
for i in kick_fail["url"]:
    print(i)
# Out:
# https://www.kickstarter.com/projects/1001433890/die-kamera?ref=ending_soon
# https://www.kickstarter.com/projects/1017791154/alaska-sharks-fund-critical-conservation-and-advoc?ref=ending_soon
# https://www.kickstarter.com/projects/1019364348/pilot-who-is-martin?ref=ending_soon
# https://www.kickstarter.com/projects/102022033/boats-n-bikes-13-part-tv-series?ref=ending_soon
# https://www.kickstarter.com/projects/1023300779/the-education-bubble-visualized?ref=ending_soon
# https://www.kickstarter.com/projects/1048578123/documentary-the-vaquita-marina?ref=ending_soon
# https://www.kickstarter.com/projects/1076937671/saving-the-thai-cats?ref=ending_soon
# https://www.kickstarter.com/projects/1077977784/ideas-camara-accion?ref=ending_soon
# https://www.kickstarter.com/projects/1088057939/el-silencio-de-marce-innocence-has-a-price?ref=ending_soon
# https://www.kickstarter.com/projects/1105227690/scar-to-angel?ref=ending_soon
# ...
